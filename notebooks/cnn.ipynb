# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from PIL import Image
from sklearn.preprocessing import LabelEncoder

import torch
from torch import nn
from torch import optim
from torchvision.transforms import transforms  #preprocess the image
from torch.utils.data import Dataset, DataLoader

import os

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
image_path = []
labels = []

for i in os.listdir(r"D:\Work_Station\DeeplearningBasics\notebooks\storage\afhq"):
    for label in os.listdir(rf"D:\Work_Station\DeeplearningBasics\notebooks\storage\afhq/{i}"):
        for image in os.listdir(rf"D:\Work_Station\DeeplearningBasics\notebooks\storage\afhq\{i}\{label}"):
            image_path.append(f"D:\Work_Station\DeeplearningBasics\notebooks\storage\afhq\{i}\{label}\{image}")
            labels.append(label)
# Out:
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\W'
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <string>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\{'
# <>:7: SyntaxWarning: invalid escape sequence '\W'
# C:\Users\shree\AppData\Local\Temp\ipykernel_11636\1793796998.py:7: SyntaxWarning: invalid escape sequence '\{'
#   image_path.append(f"D:\Work_Station\DeeplearningBasics\notebooks\storage\afhq\{i}\{label}\{image}")
# ...

# %%
data_df = pd.DataFrame(zip(image_path, labels), columns = ["image_path", "labels"])
data_df.head()
# Out:
#                                           image_path labels
# 0  D:\Work_Station\DeeplearningBasics\notebooks\s...    cat
# 1  D:\Work_Station\DeeplearningBasics\notebooks\s...    cat
# 2  D:\Work_Station\DeeplearningBasics\notebooks\s...    cat
# 3  D:\Work_Station\DeeplearningBasics\notebooks\s...    cat
# 4  D:\Work_Station\DeeplearningBasics\notebooks\s...    cat

# %%
print(data_df["labels"].unique())
# Out:
# ['cat' 'dog' 'wild']

# %%
train = data_df.sample(frac = 0.7)
test = data_df.drop(train )
